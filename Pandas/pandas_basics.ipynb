# %%
# ==========================================
# Day 7 - Pandas Fundamentals
# ==========================================

import pandas as pd

# -----------------------------
# Creating a Series
# -----------------------------

s = pd.Series([10, 20, 30, 40, 50])

print("Series:")
print(s)

# -----------------------------
# Creating a DataFrame
# -----------------------------

data = {
    "Name": ["Rahman", "Ali", "Sara"],
    "Age": [20, 21, 19],
    "City": ["Raichur", "Bangalore", "Hyderabad"]
}

df = pd.DataFrame(data)

print("\nDataFrame:")
print(df)

# -----------------------------
# Basic Information
# -----------------------------

print("\nShape:")
print(df.shape)

print("\nColumns:")
print(df.columns)

print("\nInfo:")
print(df.info())

print("\nDescription:")
print(df.describe())

# -----------------------------
# Head & Tail
# -----------------------------

print("\nHead:")
print(df.head())

print("\nTail:")
print(df.tail())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 # ==========================================
#       2 # Day 7 - Pandas Fundamentals
#       3 # ==========================================
#       4
# ----> 5 import pandas as pd
#       6
#       7 # -----------------------------
#       8 # Creating a Series
#
# File c:\Users\Abdul Rahman\OneDrive\Desktop\Abdulprac\AI-Engineer-Journey\.venv\Lib\site-packages\pandas\__init__.py:56
#      46 from pandas._config import (
#      47     get_option,
#      48     set_option,
#    (...)     52     options,
#      53 )
#      55 # let init-time option registration happen
# ---> 56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#      58 from pandas.core.api import (
#      59     # dtype
#      60     ArrowDtype,
#    (...)    119     DataFrame,
#     120 )
#     121 from pandas.core.col import col
#
# File c:\Users\Abdul Rahman\OneDrive\Desktop\Abdulprac\AI-Engineer-Journey\.venv\Lib\site-packages\pandas\core\config_init.py:31
#      19 import pandas._config.config as cf
#      20 from pandas._config.config import (
#      21     is_bool,
#      22     is_callable,
#    (...)     28     is_text,
#      29 )
# ---> 31 from pandas.errors import Pandas4Warning
#      33 # compute
#      35 use_bottleneck_doc = """
#      36 : bool
#      37     Use the bottleneck library to accelerate if it is installed,
#      38     the default is True
#      39     Valid values: False,True
#      40 """
#
# File c:\Users\Abdul Rahman\OneDrive\Desktop\Abdulprac\AI-Engineer-Journey\.venv\Lib\site-packages\pandas\errors\__init__.py:12
#       8 import ctypes
#      10 from pandas._config.config import OptionError
# ---> 12 from pandas._libs.tslibs import (
#      13     IncompatibleFrequency,
#      14     OutOfBoundsDatetime,
#      15     OutOfBoundsTimedelta,
#      16 )
#      18 from pandas.util.version import InvalidVersion
#      21 class IntCastingNaNError(ValueError):
#
# File c:\Users\Abdul Rahman\OneDrive\Desktop\Abdulprac\AI-Engineer-Journey\.venv\Lib\site-packages\pandas\_libs\__init__.py:18
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)     26     iNaT,
#      27 )
#
# File pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable.pyx:1, in init pandas._libs.hashtable()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/missing.pyx:1, in init pandas._libs.missing()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File c:\Users\Abdul Rahman\OneDrive\Desktop\Abdulprac\AI-Engineer-Journey\.venv\Lib\site-packages\pandas\_libs\tslibs\__init__.py:40
#       1 __all__ = [
#       2     "BaseOffset",
#       3     "Day",
#    (...)     37     "tz_convert_from_utc_single",
#      38 ]
# ---> 40 from pandas._libs.tslibs import dtypes
#      41 from pandas._libs.tslibs.conversion import localize_pydatetime
#      42 from pandas._libs.tslibs.dtypes import (
#      43     Resolution,
#      44     periods_per_day,
#      45     periods_per_second,
#      46 )
#
# File pandas/_libs/tslibs/dtypes.pyx:1, in init pandas._libs.tslibs.dtypes()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/ccalendar.pyx:1, in init pandas._libs.tslibs.ccalendar()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen importlib._bootstrap>:648, in ModuleSpec.parent(self)
# --> 648     @property
#     649     def parent(self):
#     650         """The name of the module's parent."""
#     651         if self.submodule_search_locations is None:
#
# KeyboardInterrupt:

# %%
# ==========================================
# Day 8 - Pandas Indexing, Selection & Filtering
# ==========================================

import pandas as pd

# -----------------------------
# Create a DataFrame
# -----------------------------

data = {
    "Name": ["Rahman", "Ali", "Sara", "Ahmed", "Fatima"],
    "Age": [20, 22, 19, 23, 21],
    "Marks": [85, 78, 92, 88, 95],
    "City": ["Raichur", "Bangalore", "Hyderabad", "Delhi", "Mumbai"]
}

df = pd.DataFrame(data)

print("Original DataFrame:\n")
print(df)

# -----------------------------
# Selecting Columns
# -----------------------------

print("\nSingle Column:")
print(df["Name"])

print("\nMultiple Columns:")
print(df[["Name", "Marks"]])

# -----------------------------
# Selecting Rows
# -----------------------------

print("\nFirst Three Rows:")
print(df[0:3])

# -----------------------------
# Using loc[]
# -----------------------------

print("\nUsing loc[]:")
print(df.loc[1])

print("\nRows 1 to 3:")
print(df.loc[1:3])

# -----------------------------
# Using iloc[]
# -----------------------------

print("\nUsing iloc[]:")
print(df.iloc[2])

print("\nRows 0 to 2:")
print(df.iloc[0:3])

# -----------------------------
# Boolean Filtering
# -----------------------------

print("\nStudents with Marks > 85")
print(df[df["Marks"] > 85])

print("\nStudents Age > 20")
print(df[df["Age"] > 20])

# -----------------------------
# Multiple Conditions
# -----------------------------

print("\nMarks > 80 and Age > 20")
print(df[(df["Marks"] > 80) & (df["Age"] > 20)])

# -----------------------------
# Sorting
# -----------------------------

print("\nSort by Marks (Ascending)")
print(df.sort_values("Marks"))

print("\nSort by Marks (Descending)")
print(df.sort_values("Marks", ascending=False))

# -----------------------------
# Reset Index
# -----------------------------

print("\nReset Index")
print(df.reset_index(drop=True))

# %%
import pandas as pd
import numpy as np

# -------------------------------------
# Day 9 - Missing Values & Data Cleaning
# -------------------------------------

data = {
    "Name": ["Rahman", "Ali", "Sara", "Ahmed", "Fatima", "Ali"],
    "Age": [20, np.nan, 19, 23, np.nan, np.nan],
    "Marks": [85, 78, np.nan, 88, 95, 78],
    "City": ["Raichur", "Bangalore", "Hyderabad", None, "Mumbai", "Bangalore"]
}

df = pd.DataFrame(data)

print("Original DataFrame")
print(df)

# Missing Values
print("\nMissing Values")
print(df.isnull())

print("\nMissing Values Count")
print(df.isnull().sum())

# Fill Missing Values
df["Age"] = df["Age"].fillna(df["Age"].mean())
df["Marks"] = df["Marks"].fillna(df["Marks"].mean())
df["City"] = df["City"].fillna("Unknown")

print("\nAfter Filling Missing Values")
print(df)

# Duplicate Rows
print("\nDuplicate Rows")
print(df.duplicated())

df = df.drop_duplicates()

print("\nAfter Removing Duplicates")
print(df)

# Rename Column
df = df.rename(columns={"Marks": "Score"})

print("\nRenamed Columns")
print(df)

# Data Summary
print("\nData Information")
print(df.info())

print("\nStatistical Summary")
print(df.describe())

# %%
import pandas as pd

# Day 10 - Data Transformation

data = {
    "Name": ["Rahman", "Ali", "Sara", "Ahmed"],
    "Gender": ["M", "M", "F", "M"],
    "Salary": [50000, 60000, 55000, 70000],
    "City": ["BLR", "HYD", "DEL", "BLR"]
}

df = pd.DataFrame(data)

print("Original DataFrame")
print(df)

# apply()
df["Salary"] = df["Salary"].apply(lambda x: x + 5000)

# map()
df["Gender"] = df["Gender"].map({"M":"Male","F":"Female"})

# replace()
df["City"] = df["City"].replace({
    "BLR":"Bangalore",
    "HYD":"Hyderabad",
    "DEL":"Delhi"
})

# String Operations
df["Upper_Name"] = df["Name"].str.upper()
df["Name_Length"] = df["Name"].str.len()

# New Column
df["Bonus"] = df["Salary"] * 0.10

print("\nUpdated DataFrame")
print(df)

# %%
import pandas as pd

# Day 11 - GroupBy Basics

data = {
    "Department":["IT","HR","IT","Finance","HR","Finance","IT"],
    "Employee":["Rahman","Ali","Sara","Ahmed","Fatima","John","David"],
    "Salary":[50000,45000,65000,70000,48000,72000,60000]
}

df = pd.DataFrame(data)

print(df)

print("\nGroup Size")
print(df.groupby("Department").size())

print("\nAverage Salary")
print(df.groupby("Department")["Salary"].mean())

print("\nMaximum Salary")
print(df.groupby("Department")["Salary"].max())

print("\nMinimum Salary")
print(df.groupby("Department")["Salary"].min())

print("\nTotal Salary")
print(df.groupby("Department")["Salary"].sum())

print("\nCount")
print(df.groupby("Department")["Salary"].count())

# %%
import pandas as pd

# Day 12 - Advanced GroupBy

data = {
    "Department":["IT","HR","IT","Finance","HR","Finance","IT"],
    "Employee":["Rahman","Ali","Sara","Ahmed","Fatima","John","David"],
    "Salary":[50000,45000,65000,70000,48000,72000,60000],
    "Experience":[2,4,3,6,5,7,2]
}

df = pd.DataFrame(data)

print(df)

print("\nMultiple Aggregations")
print(
    df.groupby("Department").agg({
        "Salary":["mean","max","min","sum"],
        "Experience":["mean","max"]
    })
)

print("\nDescribe")
print(df.groupby("Department").describe())

print("\nGet Group - IT")
print(df.groupby("Department").get_group("IT"))

print("\nIterating Groups")

for dept, group in df.groupby("Department"):
    print("\nDepartment:", dept)
    print(group)

# %%
import pandas as pd

students = pd.DataFrame({
    "ID":[1,2,3,4],
    "Name":["Rahman","Ali","Sara","Ahmed"]
})

marks = pd.DataFrame({
    "ID":[1,2,3,5],
    "Marks":[91,85,78,88]
})

print("Students")
print(students)

print("\nMarks")
print(marks)

# Inner Merge
print("\nInner Merge")
print(pd.merge(students, marks, on="ID"))

# Left Join
print("\nLeft Join")
print(pd.merge(students, marks, on="ID", how="left"))

# Right Join
print("\nRight Join")
print(pd.merge(students, marks, on="ID", how="right"))

# Outer Join
print("\nOuter Join")
print(pd.merge(students, marks, on="ID", how="outer"))

# Concatenation

df1 = pd.DataFrame({"A":[1,2],"B":[3,4]})
df2 = pd.DataFrame({"A":[5,6],"B":[7,8]})

print("\nVertical Concat")
print(pd.concat([df1,df2]))

print("\nHorizontal Concat")
print(pd.concat([df1,df2],axis=1))

# %%
import pandas as pd

data = {
    "Department":["IT","IT","HR","HR","Finance","Finance"],
    "City":["Bangalore","Delhi","Bangalore","Delhi","Delhi","Bangalore"],
    "Gender":["M","F","F","M","M","F"],
    "Salary":[50000,60000,45000,47000,65000,70000]
}

df = pd.DataFrame(data)

print("Original DataFrame")
print(df)

print("\nMean Salary by Department and City")
pivot = df.pivot_table(
    values="Salary",
    index="Department",
    columns="City",
    aggfunc="mean"
)

print(pivot)

print("\nSalary Sum")
print(df.pivot_table(values="Salary",
                     index="Department",
                     aggfunc="sum"))

print("\nCrosstab")
print(pd.crosstab(df["Department"],df["Gender"]))

print("\nMultiIndex")
multi_df = df.set_index(["Department","City"])
print(multi_df)

print("\nAccess Single Row")
print(multi_df.loc[("IT","Delhi")])

print("\nReset Index")
print(multi_df.reset_index())

# %%
import pandas as pd

data = {
    "Date": [
        "2026-07-20",
        "2026-07-21",
        "2026-07-22",
        "2026-07-23",
        "2026-07-24"
    ],
    "Sales": [500,650,420,780,620]
}

df = pd.DataFrame(data)

df["Date"] = pd.to_datetime(df["Date"])

df["Year"] = df["Date"].dt.year
df["Month"] = df["Date"].dt.month
df["Day"] = df["Date"].dt.day
df["Weekday"] = df["Date"].dt.day_name()

print(df)

print("\nSorted Data")
print(df.sort_values("Date"))

# %%
import pandas as pd

df = pd.read_csv("batsman_runs_ipl.csv")

# Check columns
print(df.columns)

# Select Single Column
print(df["batter"])

# Select Multiple Columns
print(df[["batter", "batsman_run"]])

# First 5 Rows
print(df[0:5])

# loc
print(df.loc[0:5])

# iloc
print(df.iloc[0:5])

# Filtering
print(df[df["batsman_run"] > 20])

# Multiple Conditions
print(df[(df["batsman_run"] > 20)])
# Out:
# Index(['batter', 'batsman_run'], dtype='str')
# 0      A Ashish Reddy
# 1            A Badoni
# 2          A Chandila
# 3            A Chopra
# 4         A Choudhary
#             ...
# 600        Yash Dayal
# 601     Yashpal Singh
# 602       Younis Khan
# 603      Yuvraj Singh
# 604            Z Khan
# Name: batter, Length: 605, dtype: str
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25
# 5     A Dananjaya            4
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4
# 3        A Chopra           53
# 4     A Choudhary           25
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 3          A Chopra           53
# 4       A Choudhary           25
# 6        A Flintoff           62
# ..              ...          ...
# 598       YS Chahal           37
# 599     YV Takawale          192
# 601   Yashpal Singh           47
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [420 rows x 2 columns]
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 3          A Chopra           53
# 4       A Choudhary           25
# 6        A Flintoff           62
# ..              ...          ...
# 598       YS Chahal           37
# 599     YV Takawale          192
# 601   Yashpal Singh           47
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [420 rows x 2 columns]

# %%
print(df[df["batsman_run"] > 20])
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 3          A Chopra           53
# 4       A Choudhary           25
# 6        A Flintoff           62
# ..              ...          ...
# 598       YS Chahal           37
# 599     YV Takawale          192
# 601   Yashpal Singh           47
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [420 rows x 2 columns]

# %%
import pandas as pd

df = pd.read_csv("batsman_runs_ipl.csv")

# Sorting
print(df.sort_values("batsman_run", ascending=False))

# Unique
print(df["batter"].unique())

# Number of unique batters
print(df["batter"].nunique())

# Frequency
print(df["batter"].value_counts())

# Statistics
print(df.describe())

print(df["batsman_run"].max())

print(df["batsman_run"].min())

print(df["batsman_run"].mean())

print(df["batsman_run"].median())

print(df["batsman_run"].std())
# Out:
#            batter  batsman_run
# 569       V Kohli         6634
# 462      S Dhawan         6244
# 130     DA Warner         5883
# 430     RG Sharma         5881
# 493      SK Raina         5536
# ..            ...          ...
# 512   SS Cottrell            0
# 63   Abdur Razzak            0
# 65     Akash Deep            0
# 562        U Kaul            0
# 600    Yash Dayal            0
#
# [605 rows x 2 columns]
# <StringArray>
# ['A Ashish Reddy',       'A Badoni',     'A Chandila',       'A Chopra',
#     'A Choudhary',    'A Dananjaya',     'A Flintoff',       'A Kumble',
#       'A Manohar',       'A Mishra',
#  ...
#      'YA Abdulla',    'YBK Jaiswal',      'YK Pathan',      'YS Chahal',
#     'YV Takawale',     'Yash Dayal',  'Yashpal Singh',    'Younis Khan',
#    'Yuvraj Singh',         'Z Khan']
# Length: 605, dtype: str
# 605
# batter
# A Ashish Reddy    1
# A Badoni          1
# A Chandila        1
# A Chopra          1
# A Choudhary       1
#                  ..
# Yash Dayal        1
# Yashpal Singh     1
# Younis Khan       1
# Yuvraj Singh      1
# Z Khan            1
# Name: count, Length: 605, dtype: int64
#        batsman_run
# count   605.000000
# mean    464.428099
# std     985.272855
# min       0.000000
# 25%      15.000000
# 50%      73.000000
# 75%     326.000000
# max    6634.000000
# 6634
# 0
# 464.42809917355373
# 73.0
# 985.2728553757355
